# %%
import cv2
import matplotlib.pyplot as plt
import os

# ==============================
# 📁 PATHS
# ==============================
input_path = r"D:\IPCV\LAB-EXP-1\images\1.jpeg"
output_path = r"D:\IPCV\LAB-EXP-1\resultant_img\output.png"

os.makedirs(os.path.dirname(output_path), exist_ok=True)

# ==============================
# 📷 LOAD IMAGE
# ==============================
img = cv2.imread(input_path)

if img is None:
    print("❌ Error: Image not found.")
    exit()

# Convert BGR → RGB (for correct display)
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# ==============================
# 💾 SAVE OUTPUT IMAGE
# ==============================
cv2.imwrite(output_path, img)

# ==============================
# 🖼️ DISPLAY USING MATPLOTLIB
# ==============================
plt.imshow(img_rgb)
plt.title("Acquired Image")
plt.axis('off')
plt.show()

print("✅ Image displayed successfully")
print("📄 Output saved at:", output_path)
# Out:
# ✅ Image displayed successfully
# 📄 Output saved at: D:\IPCV\LAB-EXP-1\resultant_img\output.png
